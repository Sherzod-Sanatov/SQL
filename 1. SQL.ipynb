# %% [markdown]
# Relational database - a database structured to recognize relations among stored items of information.
#
# Bog'lamli ma'lumotlar ombori - saqlangan ma'lumotlarda bog'liqlikni tushunadigan ma'lumotlar ombori.
#
# ![relational data.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# What is SQL?
# Structured query language (SQL) is a programming language for storing and processing information in a relational database. A relational database stores information in tabular form, with rows and columns representing different data attributes and the various relationships between the data values. You can use SQL statements to store, update, remove, search, and retrieve information from the database. You can also use SQL to maintain and optimize database performance.
#
# SQL nima?
# Tuzulmali so'rov tili (SQL) - bu bog'lamli ma'lumotlar omborida ma'lumotlarni saqlash va qayta ishlash uchun dasturlash tili. Bog'lamli ma'lumotlar ombori ma'lumotlarni jadval ko'rinishida saqlaydi hamda jadvaldagi ustun va qatorlar ma'lumotlar qiymati orasidagi turli aloqa va turli ma'lumotlar attribyutini namoyon etadi. Ma'lumotlar omboridan ma'lumotni olish, qidirish, o'chirish, yangilash va saqlash uchun SQL dan foydalanish mumkin. Ma'lumotlar ombori ijrosini optimizatsiya qilish uchun ham foydalanish mumkin.

# %% [markdown]
# Why is SQL important?
# Structured query language (SQL) is a popular query language that is frequently used in all types of applications. Data analysts and developers learn and use SQL because it integrates well with different programming languages. For example, they can embed SQL queries with the Java programming language to build high-performing data processing applications with major SQL database systems such as Oracle or MS SQL Server. SQL is also fairly easy to learn as it uses common English keywords in its statements.
#
# Nega SQL kerak?
# Barcha turdagi dasturlarda ommabop hisoblanadi. Dasturchilar SQL ni o'rganishadi va foydalanishadi chunki boshqa dasturlash tili bilan yaxshi birikadi. Msiol uchun Java va Oracle yoki MS SQL Server ni birga ishlatilganda yuqori natijali ma'lumotlarni qayta ishlash dasturini yaratish mumkin. SQL ni o'rganish ham oson chunki buyruqlarida keng tarqalgan inglizcha so'zlardan foydalaniladi.

# %% [markdown]
# How does SQL work?
# Structured query language (SQL) implementation involves a server machine that processes the database queries and returns the results.
#
# SQL qanday ishlaydi?
# Dasturdan kelgan so'rovlarni server yordamida qayta ishlab natijani yuboradi.

# %% [markdown]
# What is MySQL?
# MySQL is an open-source relational database management system offered by Oracle. Structured query language (SQL) is a standard language for database creation and manipulation. MySQL is a relational database program that uses SQL queries. While SQL commands are defined by international standards, the MySQL software undergoes continual upgrades and improvements.
#
# MySQL nima?
# Oracle tomonidna ishlab chiqilgan ochiq manbali va bog'lamli ma'lumotlar ombori management tizimi. SQL esa ma'lumotlarni qayta ishlash va yaratish uchun standanrd til. MySQL esa SQL so'rovlaridan foydalanadigan bog'lamli ma'lumotlar ombori dasturi. SQL da buyruqlar standard bo'lsa, MySQL dasturlash davomiy yaxshilanib o'zgartiriladi.

# %% [markdown]
# ![Screenshot 2024-04-27 at 1.15.00 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-04-27 at 1.15.10 PM.png](data:image/png;base64,...)
